# %%
import os
import numpy as np
from plotting_utils import read_data_from_logs, clean_results, check_if_minimized
from performance_profile import BASE_WORKLOADS, HELDOUT_WORKLOADS
# Out:
# /home/frank/anaconda3/envs/algoperf_pt/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
SELF_TUING = False

log_path = "../../submissions_algorithms_v0.5/logs/algoperf_scoring_v05/"
if SELF_TUING:
  log_path = os.path.join(log_path, "self_tuning")
else:
  log_path = os.path.join(log_path, "external_tuning")

full_results = read_data_from_logs(log_path)
clean_results_dict = clean_results(full_results, SELF_TUING)
# Out:
# Reading data for submission: shampoo_submission
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# Reading data for submission: prize_qualification_baseline
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['ogbg_gelu_jax', 'wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'imagenet_resnet_silu_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_layernorm_jax', 'wmt_post_ln_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'fastmri_pytorch', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax', 'fastmri_model_size_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'imagenet_resnet_silu_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'fastmri_pytorch', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['ogbg_gelu_jax', 'wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'imagenet_resnet_silu_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_layernorm_jax', 'wmt_post_ln_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax', 'fastmri_model_size_jax']
# ['ogbg_gelu_jax', 'wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'imagenet_resnet_silu_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_layernorm_jax', 'wmt_post_ln_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'fastmri_pytorch', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax', 'fastmri_model_size_jax']
# Reading data for submission: caspr_adaptive
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# Reading data for submission: schedule_free_adamw
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'trial_5', 'imagenet_vit_pytorch', 'wmt_pytorch', 'trial_1', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'trial_2', 'trial_3', 'trial_4', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'trial_5', 'imagenet_vit_pytorch', 'wmt_pytorch', 'trial_1', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'trial_2', 'trial_3', 'trial_4', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'trial_5', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'trial_2', 'trial_3', 'trial_4', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'trial_5', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'trial_2', 'trial_3', 'trial_4', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# Reading data for submission: schedule_free_prodigy
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# Reading data for submission: amos
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# Reading data for submission: lawa_ema
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# Reading data for submission: lawa_queue
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# Reading data for submission: cyclic_lr
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# ['ogbg_pytorch', 'librispeech_conformer_pytorch', 'fastmri_tanh_pytorch', 'ogbg_model_size_pytorch', 'criteo1tb_pytorch', 'librispeech_conformer_layernorm_pytorch', 'imagenet_vit_pytorch', 'wmt_pytorch', 'librispeech_deepspeech_pytorch', 'imagenet_resnet_pytorch', 'criteo1tb_embed_init_pytorch', 'fastmri_pytorch', 'imagenet_resnet_large_bn_init_pytorch', 'wmt_glu_tanh_pytorch']
# Reading data for submission: generalized_adam
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# Reading data for submission: nadamp
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']
# ['wmt_glu_tanh_jax', 'fastmri_jax', 'criteo1tb_jax', 'librispeech_conformer_layernorm_jax', 'fastmri_tanh_jax', 'ogbg_jax', 'ogbg_model_size_jax', 'imagenet_vit_jax', 'criteo1tb_embed_init_jax', 'librispeech_conformer_jax', 'librispeech_deepspeech_jax', 'wmt_jax', 'imagenet_resnet_large_bn_init_jax', 'imagenet_resnet_jax']

# %%
# Drop runs from non-selected workloads
for submission_name, submission_results in clean_results_dict.items():
    submission_results = submission_results[submission_results["workload"].isin(BASE_WORKLOADS + HELDOUT_WORKLOADS)]
    clean_results_dict[submission_name] = submission_results

# %%
def identify_bugged_runs(df, submission_name):
    # Set to true if the last global step is exactly equal to the max global step
    df["stopped_early"] = df["last_global_step"] == df["max_global_step"]
    df["rerun"] = df["stopped_early"]

    # Set to False if the validation(!) target has been achieved
    # The column "perf_is_minimized" is True if the performance metric is minimized otherwise it should be maximized,
    # this changes the comparison operator when checking if the target has been reached
    df["perf_is_minimized"] = df["validation_metric"].apply(check_if_minimized)
    df["reached_target"] = np.where(
        df["perf_is_minimized"],
        df["performance"].apply(min) < df["performance_target"],
        df["performance"].apply(max) > df["performance_target"]
    )
    df["rerun"] = df["stopped_early"] & ~df["reached_target"]

    # Don't rerun runs that have a faster tuning trial in its study
    # For each study, identify the time of the fastest run that hit the target
    for workload, group in submission_results.groupby("workload"):
        for study, group in group.groupby('study'):
            fastest_run = group["time_to_target"].min()
            df.loc[group.index, "fastest_in_study"] = fastest_run
            # If a run that stopped early is above this time, then we don't need to rerun it.
            df.loc[group.index, "rerun"]  = group["rerun"] & (group["last_submission_time"] < fastest_run)

    # Don't rerun runs that have a slower time than 3 other studies.
    for workload, group in submission_results.groupby("workload"):
        median_workload_score = group["fastest_in_study"].median()
        df.loc[group.index, "median_workload_score"] = median_workload_score
        # Any run in that workload that exceeds this time, does not need to be rerun.
        df.loc[group.index, "rerun"]  = group["rerun"] & (group["last_submission_time"] < median_workload_score)

    # Don't rerun runs if too many studies have already failed.
    for workload, group in submission_results.groupby("workload"):
        # Count the number of studies that have at least one run that is marked as rerun
        num_rerun_studies = group.groupby('study')['rerun'].any().sum()
        # Count the number of studies that have a non-inf score
        num_non_inf_studies = group.groupby('study')['time_to_target'].apply(lambda x: (~np.isinf(x)).any()).sum()
        # Compare the number of studies where a rerun could improve with the number of studies that have a non-inf score
        df.loc[group.index, "rerun"] = group["rerun"] & ~(num_rerun_studies < 3 - num_non_inf_studies)

    # Count the number of trues in the stopped_early column
    num_stopped_early = df["stopped_early"].sum()
    num_rerun = df["rerun"].sum()
    num_total_runs = len(df)
    print(f"Number of runs that need to be rerun for {submission_name}: {num_rerun}")
    # Show all rows where rerun is True
    # print(df[df["rerun"]])
    return num_stopped_early, num_rerun, num_total_runs

num_stopped_early_runs, num_reruns, num_total_runs = 0, 0, 0
for submission_name, submission_results in clean_results_dict.items():
    # if submission_name == "amos":
    num_stopped_early_runs_sub, num_reruns_sub,num_total_runs_sub = identify_bugged_runs(submission_results, submission_name)
    num_stopped_early_runs += num_stopped_early_runs_sub
    num_reruns += num_reruns_sub
    num_total_runs += num_total_runs_sub
print(f"Percentage of runs that stopped early: {num_stopped_early_runs / num_total_runs * 100:.2f}% ({num_stopped_early_runs})")
print(f"Percentage of runs that need to be rerun: {num_reruns / num_total_runs * 100:.2f}% ({num_reruns})")
# Out:
# Number of runs that need to be rerun for shampoo_submission: 0
# Number of runs that need to be rerun for prize_qualification_baseline: 6
# Number of runs that need to be rerun for caspr_adaptive: 0
# Number of runs that need to be rerun for schedule_free_adamw: 0
# Number of runs that need to be rerun for schedule_free_prodigy: 0
# Number of runs that need to be rerun for amos: 0
# Number of runs that need to be rerun for lawa_ema: 0
# Number of runs that need to be rerun for lawa_queue: 0
# Number of runs that need to be rerun for cyclic_lr: 0
# Number of runs that need to be rerun for generalized_adam: 0
# Number of runs that need to be rerun for nadamp: 7
# Percentage of runs that stopped early: 13.55% (495)
# Percentage of runs that need to be rerun: 0.36% (13)

# %%
df = clean_results_dict["cyclic_lr"]
df[df["rerun"] == True]
# df
# Out:
#                           workload    study    trial  time_to_target  \
# 100  imagenet_resnet_large_bn_init  study_0  trial_1             inf
# 101  imagenet_resnet_large_bn_init  study_0  trial_2             inf
# 102  imagenet_resnet_large_bn_init  study_0  trial_3             inf
# 103  imagenet_resnet_large_bn_init  study_0  trial_4             inf
# 104  imagenet_resnet_large_bn_init  study_0  trial_5             inf
# 105  imagenet_resnet_large_bn_init  study_1  trial_1             inf
# 106  imagenet_resnet_large_bn_init  study_1  trial_2             inf
# 107  imagenet_resnet_large_bn_init  study_1  trial_3             inf
# 108  imagenet_resnet_large_bn_init  study_1  trial_4             inf
# 109  imagenet_resnet_large_bn_init  study_1  trial_5             inf
# 110  imagenet_resnet_large_bn_init  study_2  trial_1             inf
# 111  imagenet_resnet_large_bn_init  study_2  trial_2             inf
# 112  imagenet_resnet_large_bn_init  study_2  trial_3             inf
# 113  imagenet_resnet_large_bn_init  study_2  trial_4             inf
# 114  imagenet_resnet_large_bn_init  study_2  trial_5             inf
# 115  imagenet_resnet_large_bn_init  study_3  trial_1             inf
# 116  imagenet_resnet_large_bn_init  study_3  trial_2             inf
# 117  imagenet_resnet_large_bn_init  study_3  trial_3             inf
# 118  imagenet_resnet_large_bn_init  study_3  trial_4             inf
# 119  imagenet_resnet_large_bn_init  study_3  trial_5             inf
# 120  imagenet_resnet_large_bn_init  study_4  trial_1             inf
# 121  imagenet_resnet_large_bn_init  study_4  trial_2             inf
# 122  imagenet_resnet_large_bn_init  study_4  trial_3             inf
# 123  imagenet_resnet_large_bn_init  study_4  trial_4             inf
# 124  imagenet_resnet_large_bn_init  study_4  trial_5             inf
#
#                                                runtime  \
# 100  [108.67666983604433, 616.4995930194855, 1124.3...
# 101  [108.09170889854433, 615.9908201694489, 1123.8...
# 102  [108.26602697372437, 616.0899803638458, 1124.0...
# 103  [106.49785113334656, 614.4587249755859, 1122.4...
# 104  [107.14069032669067, 615.0062892436981, 1122.8...
# 105  [108.123605966568, 615.9082245826721, 1123.916...
# 106  [107.73529601097108, 615.5508902072906, 1123.5...
# 107  [108.13523364067078, 615.8964159488678, 1123.7...
# 108  [107.40123319625854, 615.284832239151, 1123.29...
# 109  [108.1041738986969, 615.7369914054871, 1123.51...
# 110  [108.52269554138184, 616.2088623046875, 1124.1...
# 111  [107.01756715774536, 614.8528118133545, 1122.8...
# 112  [108.05704188346864, 615.9082343578339, 1123.8...
# 113  [109.42130208015442, 617.2138378620148, 1125.0...
# 114  [107.83097052574158, 615.5014216899872, 1123.3...
# 115  [108.64490818977356, 616.4217803478241, 1124.3...
# 116  [106.26311016082764, 614.1329729557037, 1122.0...
# 117  [107.96868968009947, 615.6864461898804, 1123.5...
# 118  [107.20417428016664, 615.0547523498535, 1122.9...
# 119  [108.39798283576964, 616.090573310852, 1124.07...
# 120  [107.15620875358582, 614.967794418335, 1122.94...
# 121  [106.62891888618468, 614.5443148612976, 1122.5...
# 122  [108.40218830108644, 616.2748293876648, 1124.2...
# 123  [106.42344427108765, 614.3143379688263, 1122.2...
# 124  [108.45287942886353, 616.1306915283203, 1124.0...
#
#                                            performance    validation_metric  \
# 100  [0.001, 0.0682, 0.18028, 0.15948, 0.30378, 0.3...  validation/accuracy
# 101  [0.001, 0.04144, 0.15404, 0.2591, 0.35324, 0.3...  validation/accuracy
# 102  [0.001, 0.09756, 0.26284, 0.40116, 0.46478, 0....  validation/accuracy
# 103  [0.001, 0.04238, 0.17066, 0.27692, 0.35268, 0....  validation/accuracy
# 104  [0.001, 0.05962, 0.27406, 0.33236, 0.45294, 0....  validation/accuracy
# 105  [0.001, 0.05774, 0.05504, 0.22124, 0.24342, 0....  validation/accuracy
# 106  [0.001, 0.04108, 0.16094, 0.27576, 0.3267, 0.2...  validation/accuracy
# 107  [0.001, 0.0653, 0.2257, 0.37492, 0.45372, 0.20...  validation/accuracy
# 108  [0.001, 0.04144, 0.15976, 0.2096, 0.33774, 0.3...  validation/accuracy
# 109  [0.001, 0.0794, 0.23414, 0.37104, 0.4414, 0.46...  validation/accuracy
# 110  [0.001, 0.06606, 0.1711, 0.24354, 0.33418, 0.3...  validation/accuracy
# 111  [0.001, 0.04352, 0.18162, 0.28814, 0.36262, 0....  validation/accuracy
# 112  [0.001, 0.09542, 0.26496, 0.4072, 0.46586, 0.5...  validation/accuracy
# 113  [0.001, 0.03858, 0.17206, 0.26468, 0.32608, 0....  validation/accuracy
# 114  [0.001, 0.09964, 0.28402, 0.40798, 0.45102, 0....  validation/accuracy
# 115  [0.00098, 0.06946, 0.16166, 0.27514, 0.32052, ...  validation/accuracy
# 116  [0.001, 0.0427, 0.15258, 0.25252, 0.35606, 0.3...  validation/accuracy
# 117  [0.001, 0.07932, 0.2237, 0.36912, 0.44546, 0.4...  validation/accuracy
# 118  [0.001, 0.04662, 0.17352, 0.22618, 0.33636, 0....  validation/accuracy
# 119  [0.001, 0.06514, 0.26462, 0.39448, 0.43526, 0....  validation/accuracy
# 120  [0.001, 0.07268, 0.19724, 0.2537, 0.30208, 0.3...  validation/accuracy
# 121  [0.001, 0.03952, 0.16302, 0.28402, 0.27588, 0....  validation/accuracy
# 122  [0.001, 0.06526, 0.2794, 0.41084, 0.46874, 0.4...  validation/accuracy
# 123  [0.001, 0.04264, 0.17314, 0.2851, 0.34008, 0.3...  validation/accuracy
# 124  [0.001, 0.07152, 0.2329, 0.38552, 0.42884, 0.4...  validation/accuracy
#
#      performance_target  runtime_budget  last_global_step  \
# 100             0.76526           63008            186666
# 101             0.76526           63008            186666
# 102             0.76526           63008            186666
# 103             0.76526           63008            186666
# 104             0.76526           63008            186666
# 105             0.76526           63008            186666
# 106             0.76526           63008            186666
# 107             0.76526           63008            186666
# 108             0.76526           63008            186666
# 109             0.76526           63008            186666
# 110             0.76526           63008            186666
# 111             0.76526           63008            186666
# 112             0.76526           63008            186666
# 113             0.76526           63008            186666
# 114             0.76526           63008            186666
# 115             0.76526           63008            186666
# 116             0.76526           63008            186666
# 117             0.76526           63008            186666
# 118             0.76526           63008            186666
# 119             0.76526           63008            186666
# 120             0.76526           63008            186666
# 121             0.76526           63008            186666
# 122             0.76526           63008            186666
# 123             0.76526           63008            186666
# 124             0.76526           63008            186666
#
#      last_submission_time  last_performance  max_global_step  stopped_early  \
# 100          40511.677660           0.75634           186666           True
# 101          40327.383247           0.75858           186666           True
# 102          40409.709540           0.76068           186666           True
# 103          40281.963847           0.75116           186666           True
# 104          40518.136041           0.75352           186666           True
# 105          40701.223892           0.75884           186666           True
# 106          40538.644940           0.75758           186666           True
# 107          40623.108612           0.75766           186666           True
# 108          40231.963471           0.74908           186666           True
# 109          40475.431898           0.75648           186666           True
# 110          41026.201952           0.76234           186666           True
# 111          39970.391780           0.75884           186666           True
# 112          40532.972186           0.76018           186666           True
# 113          40509.153548           0.75390           186666           True
# 114          40866.027204           0.75834           186666           True
# 115          40427.844599           0.76392           186666           True
# 116          40016.571254           0.75474           186666           True
# 117          40450.849560           0.76124           186666           True
# 118          40145.421627           0.74926           186666           True
# 119          40500.098474           0.75686           186666           True
# 120          40270.278817           0.76184           186666           True
# 121          40107.496418           0.76020           186666           True
# 122          40611.503576           0.76122           186666           True
# 123          40027.103651           0.75316           186666           True
# 124          40491.283242           0.75498           186666           True
#
#      rerun  perf_is_minimized  reached_target  fastest_in_study  \
# 100   True              False           False               inf
# 101   True              False           False               inf
# 102   True              False           False               inf
# 103   True              False           False               inf
# 104   True              False           False               inf
# 105   True              False           False               inf
# 106   True              False           False               inf
# 107   True              False           False               inf
# 108   True              False           False               inf
# 109   True              False           False               inf
# 110   True              False           False               inf
# 111   True              False           False               inf
# 112   True              False           False               inf
# 113   True              False           False               inf
# 114   True              False           False               inf
# 115   True              False           False               inf
# 116   True              False           False               inf
# 117   True              False           False               inf
# 118   True              False           False               inf
# 119   True              False           False               inf
# 120   True              False           False               inf
# 121   True              False           False               inf
# 122   True              False           False               inf
# 123   True              False           False               inf
# 124   True              False           False               inf
#
#      median_workload_score
# 100                    inf
# 101                    inf
# 102                    inf
# 103                    inf
# 104                    inf
# 105                    inf
# 106                    inf
# 107                    inf
# 108                    inf
# 109                    inf
# 110                    inf
# 111                    inf
# 112                    inf
# 113                    inf
# 114                    inf
# 115                    inf
# 116                    inf
# 117                    inf
# 118                    inf
# 119                    inf
# 120                    inf
# 121                    inf
# 122                    inf
# 123                    inf
# 124                    inf

# %%
df[df["workload"] == "librispeech_deepspeech"]
